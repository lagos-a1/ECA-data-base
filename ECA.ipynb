# %% [markdown]
# <a href="https://colab.research.google.com/github/lagos-a1/ECA-data-base/blob/master/ECA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import io
from datetime import date
from google.colab import files

# %%
uploaded = files.upload()
df = pd.read_csv(io.StringIO(uploaded['Format1.csv'].decode('utf-8')))
# Out:
#      <input type="file" id="files-73099f35-6cb0-49ca-ad62-70ad631b6f6d" name="files[]" multiple disabled />
#      <output id="result-73099f35-6cb0-49ca-ad62-70ad631b6f6d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Format1.csv to Format1 (2).csv

# %%
BackupDF = df.copy()
df
# Out:
# Empty DataFrame
# Columns: [SiteCode, SiteName, SubSiteName, IsSiteActive, IsSiteShared, Addr1, Addr2, Addr3, Suburb, State, PostCode, Country, PostalAddr1, PostalAddr2, PostalAddr3, PostalSuburb, PostalState, PostalPostCode, PostalCountry, WebAddress, SiteEmail, SiteAlternateEmail, Phone1, Phone2, Fax, Sector, SiteComment, PrivateSiteComment, ContactCode, ContactPosition, ContactTitle, ContactFirstName, ContactMiddleName, ContactSurname, ContactQualifications, ContactEmail, ContactAlternateEmail, ContactPhWork, ContactPhMobile, ContactGender, ContactIsPrimary, ContactIsStudentContact, ContactIsAccessibilityEnabled, SiteDescriptors, SiteAreas, SiteFocuses, SiteRegions, AgreementProvider, AgreementIssueDate, AgreementExpiryDate, LocationGroup, Location]
# Index: []

# %%
uploaded1 = files.upload()
df1 = pd.read_csv(io.StringIO(uploaded1['Host Company.csv'].decode('utf-8')))
# Out:
#      <input type="file" id="files-37643263-6154-4557-aec5-ddb350e7afc3" name="files[]" multiple disabled />
#      <output id="result-37643263-6154-4557-aec5-ddb350e7afc3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Host Company.csv to Host Company (1).csv

# %%
df1
# Out:
#       CC_Id  ... Num_CompanyJobRoles
# 0         1  ...                   2
# 1         3  ...                   3
# 2         4  ...                   1
# 3         6  ...                   2
# 4         7  ...                   1
# ...     ...  ...                 ...
# 1942   3057  ...                   1
# 1943   3058  ...                   1
# 1944   3059  ...                   1
# 1945   3060  ...                   1
# 1946   3061  ...                   1
#
# [1947 rows x 23 columns]

# %%
uploaded2 = files.upload()
df2 = pd.read_csv(io.StringIO(uploaded2['datesBase.csv'].decode('utf-8')))
# Out:
#      <input type="file" id="files-5467cd66-44ea-4a74-af90-9118c5657b34" name="files[]" multiple disabled />
#      <output id="result-5467cd66-44ea-4a74-af90-9118c5657b34">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving datesBase.csv to datesBase (1).csv

# %%
df2
# Out:
#      CC_id  ... Check box if BD Team Needs to Follow Up
# 0      164  ...                                     NaN
# 1      252  ...                                     NaN
# 2        1  ...                                     NaN
# 3      506  ...                                     NaN
# 4        4  ...                                     NaN
# ..     ...  ...                                     ...
# 389   1566  ...                                     NaN
# 390   1122  ...                                     NaN
# 391   1246  ...                                     NaN
# 392    725  ...                                     NaN
# 393    155  ...                                     NaN
#
# [394 rows x 17 columns]

# %%
df['SiteCode']= df1['CC_Id'] 
df['SiteName']= df1['CompanyName'] 
df
# Out:
#       SiteCode  ... Location
# 0            1  ...      NaN
# 1            3  ...      NaN
# 2            4  ...      NaN
# 3            6  ...      NaN
# 4            7  ...      NaN
# ...        ...  ...      ...
# 1942      3057  ...      NaN
# 1943      3058  ...      NaN
# 1944      3059  ...      NaN
# 1945      3060  ...      NaN
# 1946      3061  ...      NaN
#
# [1947 rows x 52 columns]
